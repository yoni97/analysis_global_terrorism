# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../csv_files/globalterrorismdb.csv', encoding='latin1')
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1700\2213551428.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../csv_files/globalterrorismdb.csv', encoding='latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 'provstate':'state',
                     'region_txt':'Region', 'attacktype1_txt':'AttackType', 'target1':'Target', 'nkill':'Killed',
                     'nwound':'Wounded', 'summary':'Summary', 'gname':'Group', 'targtype1_txt':'Target_type',
                     'weaptype1_txt':'Weapon_type', 'nperps': 'nperps'
                    },inplace=True)
df
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country             Country  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df = df[['eventid','Year','Month','Day','Country','Region','state','city','latitude','longitude','AttackType','Killed','Wounded',
            'Target','Summary','Group','Target_type','Weapon_type', 'nperps', 'success']]
df
# Out:
#              eventid  Year  Month  Day             Country  \
# 0       197000000001  1970      7    2  Dominican Republic
# 1       197000000002  1970      0    0              Mexico
# 2       197001000001  1970      1    0         Philippines
# 3       197001000002  1970      1    0              Greece
# 4       197001000003  1970      1    0               Japan
# ...              ...   ...    ...  ...                 ...
# 181686  201712310022  2017     12   31             Somalia
# 181687  201712310029  2017     12   31               Syria
# 181688  201712310030  2017     12   31         Philippines
# 181689  201712310031  2017     12   31               India
# 181690  201712310032  2017     12   31         Philippines
#
#                              Region            state           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude                      AttackType  Killed  \
# 0       18.456792  -69.951164                   Assassination     1.0
# 1       19.371887  -99.086624     Hostage Taking (Kidnapping)     0.0
# 2       15.478598  120.599741                   Assassination     1.0
# 3       37.997490   23.762728               Bombing/Explosion     NaN
# 4       33.580412  130.396361  Facility/Infrastructure Attack     NaN
# ...           ...         ...                             ...     ...
# 181686   2.359673   45.385034                   Armed Assault     1.0
# 181687  35.407278   35.942679               Bombing/Explosion     2.0
# 181688   6.900742  124.437908  Facility/Infrastructure Attack     0.0
# 181689  24.798346   93.940430               Bombing/Explosion     0.0
# 181690   7.209594  124.241966               Bombing/Explosion     0.0
#
#         Wounded                   Target  \
# 0           0.0             Julio Guzman
# 1           0.0  Nadine Chaval, daughter
# 2           0.0                 Employee
# 3           NaN             U.S. Embassy
# 4           NaN           U.S. Consulate
# ...         ...                      ...
# 181686      2.0               Checkpoint
# 181687      7.0         Hmeymim Air Base
# 181688      0.0                   Houses
# 181689      0.0                   Office
# 181690      0.0                  Unknown
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 0                                           MANO-D
# 1               23rd of September Communist League
# 2                                          Unknown
# 3                                          Unknown
# 4                                          Unknown
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type  nperps  success
# 0       Private Citizens & Property     Unknown     NaN        1
# 1           Government (Diplomatic)     Unknown     7.0        1
# 2               Journalists & Media     Unknown     NaN        1
# 3           Government (Diplomatic)  Explosives     NaN        1
# 4           Government (Diplomatic)  Incendiary     NaN        1
# ...                             ...         ...     ...      ...
# 181686                     Military    Firearms   -99.0        1
# 181687                     Military  Explosives   -99.0        1
# 181688  Private Citizens & Property  Incendiary   -99.0        1
# 181689         Government (General)  Explosives   -99.0        0
# 181690                      Unknown  Explosives   -99.0        0
#
# [181691 rows x 20 columns]

# %%
print("Country with the most attacks:",df['Country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1]) #first entry is 'unknown'
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Month with the most attacks:",df['Month'].value_counts().idxmax())
print("Group with the most attacks:",df['Group'].value_counts().index[1])
print("Most Attack Types:",df['Weapon_type'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Explosives

# %%
df.loc[:, 'Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']], errors='coerce')
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1700\846673521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']], errors='coerce')
#              eventid  Year  Month  Day             Country  \
# 0       197000000001  1970      7    2  Dominican Republic
# 1       197000000002  1970      0    0              Mexico
# 2       197001000001  1970      1    0         Philippines
# 3       197001000002  1970      1    0              Greece
# 4       197001000003  1970      1    0               Japan
# ...              ...   ...    ...  ...                 ...
# 181686  201712310022  2017     12   31             Somalia
# 181687  201712310029  2017     12   31               Syria
# 181688  201712310030  2017     12   31         Philippines
# 181689  201712310031  2017     12   31               India
# 181690  201712310032  2017     12   31         Philippines
#
#                              Region            state           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude  ... Killed  Wounded                   Target  \
# 0       18.456792  -69.951164  ...    1.0      0.0             Julio Guzman
# 1       19.371887  -99.086624  ...    0.0      0.0  Nadine Chaval, daughter
# 2       15.478598  120.599741  ...    1.0      0.0                 Employee
# 3       37.997490   23.762728  ...    NaN      NaN             U.S. Embassy
# 4       33.580412  130.396361  ...    NaN      NaN           U.S. Consulate
# ...           ...         ...  ...    ...      ...                      ...
# 181686   2.359673   45.385034  ...    1.0      2.0               Checkpoint
# 181687  35.407278   35.942679  ...    2.0      7.0         Hmeymim Air Base
# 181688   6.900742  124.437908  ...    0.0      0.0                   Houses
# 181689  24.798346   93.940430  ...    0.0      0.0                   Office
# 181690   7.209594  124.241966  ...    0.0      0.0                  Unknown
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 0                                           MANO-D
# 1               23rd of September Communist League
# 2                                          Unknown
# 3                                          Unknown
# 4                                          Unknown
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type nperps  success       Date
# 0       Private Citizens & Property     Unknown    NaN        1 1970-07-02
# 1           Government (Diplomatic)     Unknown    7.0        1        NaT
# 2               Journalists & Media     Unknown    NaN        1        NaT
# 3           Government (Diplomatic)  Explosives    NaN        1        NaT
# 4           Government (Diplomatic)  Incendiary    NaN        1        NaT
# ...                             ...         ...    ...      ...        ...
# 181686                     Military    Firearms  -99.0        1 2017-12-31
# 181687                     Military  Explosives  -99.0        1 2017-12-31
# 181688  Private Citizens & Property  Incendiary  -99.0        1 2017-12-31
# 181689         Government (General)  Explosives  -99.0        0 2017-12-31
# 181690                      Unknown  Explosives  -99.0        0 2017-12-31
#
# [181691 rows x 21 columns]

# %%
df.fillna(0)
df
# Out:
#              eventid  Year  Month  Day             Country  \
# 0       197000000001  1970      7    2  Dominican Republic
# 1       197000000002  1970      0    0              Mexico
# 2       197001000001  1970      1    0         Philippines
# 3       197001000002  1970      1    0              Greece
# 4       197001000003  1970      1    0               Japan
# ...              ...   ...    ...  ...                 ...
# 181686  201712310022  2017     12   31             Somalia
# 181687  201712310029  2017     12   31               Syria
# 181688  201712310030  2017     12   31         Philippines
# 181689  201712310031  2017     12   31               India
# 181690  201712310032  2017     12   31         Philippines
#
#                              Region            state           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude  ... Killed  Wounded                   Target  \
# 0       18.456792  -69.951164  ...    1.0      0.0             Julio Guzman
# 1       19.371887  -99.086624  ...    0.0      0.0  Nadine Chaval, daughter
# 2       15.478598  120.599741  ...    1.0      0.0                 Employee
# 3       37.997490   23.762728  ...    NaN      NaN             U.S. Embassy
# 4       33.580412  130.396361  ...    NaN      NaN           U.S. Consulate
# ...           ...         ...  ...    ...      ...                      ...
# 181686   2.359673   45.385034  ...    1.0      2.0               Checkpoint
# 181687  35.407278   35.942679  ...    2.0      7.0         Hmeymim Air Base
# 181688   6.900742  124.437908  ...    0.0      0.0                   Houses
# 181689  24.798346   93.940430  ...    0.0      0.0                   Office
# 181690   7.209594  124.241966  ...    0.0      0.0                  Unknown
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 0                                           MANO-D
# 1               23rd of September Communist League
# 2                                          Unknown
# 3                                          Unknown
# 4                                          Unknown
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type nperps  success       Date
# 0       Private Citizens & Property     Unknown    NaN        1 1970-07-02
# 1           Government (Diplomatic)     Unknown    7.0        1        NaT
# 2               Journalists & Media     Unknown    NaN        1        NaT
# 3           Government (Diplomatic)  Explosives    NaN        1        NaT
# 4           Government (Diplomatic)  Incendiary    NaN        1        NaT
# ...                             ...         ...    ...      ...        ...
# 181686                     Military    Firearms  -99.0        1 2017-12-31
# 181687                     Military  Explosives  -99.0        1 2017-12-31
# 181688  Private Citizens & Property  Incendiary  -99.0        1 2017-12-31
# 181689         Government (General)  Explosives  -99.0        0 2017-12-31
# 181690                      Unknown  Explosives  -99.0        0 2017-12-31
#
# [181691 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'Country', 'Region', 'state', 'city',
#        'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type', 'nperps', 'success',
#        'Date'],
#       dtype='object')

# %%
# required_columns = [
    # Event
    # 'iyear', 'imonth', 'iday', 'latitude', 'longitude', 'summary', 'nperps'

    # Group
    # 'gname',

    # AttackType
    # 'attacktype1', 'attacktype1_txt',

    # TargetType
    # 'targtype1', 'targtype1_txt',

    # Casualties
    # 'nkill', 'nwound',

    # Region
    # 'region', 'region_txt',

    # Country
    # 'country', 'country_txt',

    # City
    # 'city'

# %%
df['severity'] = df['Killed'].fillna(0) * 2 + df['Wounded'].fillna(0)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1700\2863290102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['severity'] = df['Killed'].fillna(0) * 2 + df['Wounded'].fillna(0)
#              eventid  Year  Month  Day             Country  \
# 0       197000000001  1970      7    2  Dominican Republic
# 1       197000000002  1970      0    0              Mexico
# 2       197001000001  1970      1    0         Philippines
# 3       197001000002  1970      1    0              Greece
# 4       197001000003  1970      1    0               Japan
# ...              ...   ...    ...  ...                 ...
# 181686  201712310022  2017     12   31             Somalia
# 181687  201712310029  2017     12   31               Syria
# 181688  201712310030  2017     12   31         Philippines
# 181689  201712310031  2017     12   31               India
# 181690  201712310032  2017     12   31         Philippines
#
#                              Region            state           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude  ... Wounded                   Target  \
# 0       18.456792  -69.951164  ...     0.0             Julio Guzman
# 1       19.371887  -99.086624  ...     0.0  Nadine Chaval, daughter
# 2       15.478598  120.599741  ...     0.0                 Employee
# 3       37.997490   23.762728  ...     NaN             U.S. Embassy
# 4       33.580412  130.396361  ...     NaN           U.S. Consulate
# ...           ...         ...  ...     ...                      ...
# 181686   2.359673   45.385034  ...     2.0               Checkpoint
# 181687  35.407278   35.942679  ...     7.0         Hmeymim Air Base
# 181688   6.900742  124.437908  ...     0.0                   Houses
# 181689  24.798346   93.940430  ...     0.0                   Office
# 181690   7.209594  124.241966  ...     0.0                  Unknown
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 0                                           MANO-D
# 1               23rd of September Communist League
# 2                                          Unknown
# 3                                          Unknown
# 4                                          Unknown
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type nperps success       Date  \
# 0       Private Citizens & Property     Unknown    NaN       1 1970-07-02
# 1           Government (Diplomatic)     Unknown    7.0       1        NaT
# 2               Journalists & Media     Unknown    NaN       1        NaT
# 3           Government (Diplomatic)  Explosives    NaN       1        NaT
# 4           Government (Diplomatic)  Incendiary    NaN       1        NaT
# ...                             ...         ...    ...     ...        ...
# 181686                     Military    Firearms  -99.0       1 2017-12-31
# 181687                     Military  Explosives  -99.0       1 2017-12-31
# 181688  Private Citizens & Property  Incendiary  -99.0       1 2017-12-31
# 181689         Government (General)  Explosives  -99.0       0 2017-12-31
# 181690                      Unknown  Explosives  -99.0       0 2017-12-31
#
#         severity
# 0            2.0
# 1            0.0
# 2            2.0
# 3            0.0
# 4            0.0
# ...          ...
# 181686       4.0
# 181687      11.0
# 181688       0.0
# 181689       0.0
# 181690       0.0
#
# [181691 rows x 22 columns]

# %%
df['nperps'] = df['nperps'].apply(lambda x: np.nan if x < 0 else x)
df['Wounded'] = df['Wounded'].apply(lambda x: np.nan if x < 0 else x)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1700\343003825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nperps'] = df['nperps'].apply(lambda x: np.nan if x < 0 else x)
# C:\Users\User\AppData\Local\Temp\ipykernel_1700\343003825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wounded'] = df['Wounded'].apply(lambda x: np.nan if x < 0 else x)

# %%
df.loc[df['nperps'] < 0, 'nperps'] = np.nan
df.loc[df['Wounded'] < 0, 'Wounded'] = np.nan
df
# Out:
#              eventid  Year  Month  Day             Country  \
# 0       197000000001  1970      7    2  Dominican Republic
# 1       197000000002  1970      0    0              Mexico
# 2       197001000001  1970      1    0         Philippines
# 3       197001000002  1970      1    0              Greece
# 4       197001000003  1970      1    0               Japan
# ...              ...   ...    ...  ...                 ...
# 181686  201712310022  2017     12   31             Somalia
# 181687  201712310029  2017     12   31               Syria
# 181688  201712310030  2017     12   31         Philippines
# 181689  201712310031  2017     12   31               India
# 181690  201712310032  2017     12   31         Philippines
#
#                              Region            state           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude  ... Wounded                   Target  \
# 0       18.456792  -69.951164  ...     0.0             Julio Guzman
# 1       19.371887  -99.086624  ...     0.0  Nadine Chaval, daughter
# 2       15.478598  120.599741  ...     0.0                 Employee
# 3       37.997490   23.762728  ...     NaN             U.S. Embassy
# 4       33.580412  130.396361  ...     NaN           U.S. Consulate
# ...           ...         ...  ...     ...                      ...
# 181686   2.359673   45.385034  ...     2.0               Checkpoint
# 181687  35.407278   35.942679  ...     7.0         Hmeymim Air Base
# 181688   6.900742  124.437908  ...     0.0                   Houses
# 181689  24.798346   93.940430  ...     0.0                   Office
# 181690   7.209594  124.241966  ...     0.0                  Unknown
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 0                                           MANO-D
# 1               23rd of September Communist League
# 2                                          Unknown
# 3                                          Unknown
# 4                                          Unknown
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type nperps success       Date  \
# 0       Private Citizens & Property     Unknown    NaN       1 1970-07-02
# 1           Government (Diplomatic)     Unknown    7.0       1        NaT
# 2               Journalists & Media     Unknown    NaN       1        NaT
# 3           Government (Diplomatic)  Explosives    NaN       1        NaT
# 4           Government (Diplomatic)  Incendiary    NaN       1        NaT
# ...                             ...         ...    ...     ...        ...
# 181686                     Military    Firearms    NaN       1 2017-12-31
# 181687                     Military  Explosives    NaN       1 2017-12-31
# 181688  Private Citizens & Property  Incendiary    NaN       1 2017-12-31
# 181689         Government (General)  Explosives    NaN       0 2017-12-31
# 181690                      Unknown  Explosives    NaN       0 2017-12-31
#
#         severity
# 0            2.0
# 1            0.0
# 2            2.0
# 3            0.0
# 4            0.0
# ...          ...
# 181686       4.0
# 181687      11.0
# 181688       0.0
# 181689       0.0
# 181690       0.0
#
# [181691 rows x 22 columns]

# %%
df.to_csv('normalized_data.csv', index=False)
print('Successfully saved normalized data')
# Out:
# Successfully saved normalized data

# %%
nd = pd.read_csv('normalized_data.csv', index_col=0)
nd
# Out:
#               Year  Month  Day             Country  \
# eventid
# 197000000001  1970      7    2  Dominican Republic
# 197000000002  1970      0    0              Mexico
# 197001000001  1970      1    0         Philippines
# 197001000002  1970      1    0              Greece
# 197001000003  1970      1    0               Japan
# ...            ...    ...  ...                 ...
# 201712310022  2017     12   31             Somalia
# 201712310029  2017     12   31               Syria
# 201712310030  2017     12   31         Philippines
# 201712310031  2017     12   31               India
# 201712310032  2017     12   31         Philippines
#
#                                    Region            state           city  \
# eventid
# 197000000001  Central America & Caribbean              NaN  Santo Domingo
# 197000000002                North America          Federal    Mexico city
# 197001000001               Southeast Asia           Tarlac        Unknown
# 197001000002               Western Europe           Attica         Athens
# 197001000003                    East Asia          Fukouka        Fukouka
# ...                                   ...              ...            ...
# 201712310022           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 201712310029   Middle East & North Africa         Lattakia         Jableh
# 201712310030               Southeast Asia      Maguindanao       Kubentog
# 201712310031                   South Asia          Manipur         Imphal
# 201712310032               Southeast Asia      Maguindanao  Cotabato City
#
#                latitude   longitude                      AttackType  ...  \
# eventid                                                              ...
# 197000000001  18.456792  -69.951164                   Assassination  ...
# 197000000002  19.371887  -99.086624     Hostage Taking (Kidnapping)  ...
# 197001000001  15.478598  120.599741                   Assassination  ...
# 197001000002  37.997490   23.762728               Bombing/Explosion  ...
# 197001000003  33.580412  130.396361  Facility/Infrastructure Attack  ...
# ...                 ...         ...                             ...  ...
# 201712310022   2.359673   45.385034                   Armed Assault  ...
# 201712310029  35.407278   35.942679               Bombing/Explosion  ...
# 201712310030   6.900742  124.437908  Facility/Infrastructure Attack  ...
# 201712310031  24.798346   93.940430               Bombing/Explosion  ...
# 201712310032   7.209594  124.241966               Bombing/Explosion  ...
#
#               Wounded                   Target  \
# eventid
# 197000000001      0.0             Julio Guzman
# 197000000002      0.0  Nadine Chaval, daughter
# 197001000001      0.0                 Employee
# 197001000002      NaN             U.S. Embassy
# 197001000003      NaN           U.S. Consulate
# ...               ...                      ...
# 201712310022      2.0               Checkpoint
# 201712310029      7.0         Hmeymim Air Base
# 201712310030      0.0                   Houses
# 201712310031      0.0                   Office
# 201712310032      0.0                  Unknown
#
#                                                         Summary  \
# eventid
# 197000000001                                                NaN
# 197000000002                                                NaN
# 197001000001                                                NaN
# 197001000002                                                NaN
# 197001000003                                                NaN
# ...                                                         ...
# 201712310022  12/31/2017: Assailants opened fire on a Somali...
# 201712310029  12/31/2017: Assailants launched mortars at the...
# 201712310030  12/31/2017: Assailants set fire to houses in K...
# 201712310031  12/31/2017: Assailants threw a grenade at a Fo...
# 201712310032  12/31/2017: An explosive device was discovered...
#
#                                                    Group  \
# eventid
# 197000000001                                      MANO-D
# 197000000002          23rd of September Communist League
# 197001000001                                     Unknown
# 197001000002                                     Unknown
# 197001000003                                     Unknown
# ...                                                  ...
# 201712310022                                  Al-Shabaab
# 201712310029                           Muslim extremists
# 201712310030  Bangsamoro Islamic Freedom Movement (BIFM)
# 201712310031                                     Unknown
# 201712310032                                     Unknown
#
#                               Target_type Weapon_type nperps  success  \
# eventid
# 197000000001  Private Citizens & Property     Unknown    NaN        1
# 197000000002      Government (Diplomatic)     Unknown    7.0        1
# 197001000001          Journalists & Media     Unknown    NaN        1
# 197001000002      Government (Diplomatic)  Explosives    NaN        1
# 197001000003      Government (Diplomatic)  Incendiary    NaN        1
# ...                                   ...         ...    ...      ...
# 201712310022                     Military    Firearms    NaN        1
# 201712310029                     Military  Explosives    NaN        1
# 201712310030  Private Citizens & Property  Incendiary    NaN        1
# 201712310031         Government (General)  Explosives    NaN        0
# 201712310032                      Unknown  Explosives    NaN        0
#
#                     Date severity
# eventid
# 197000000001  1970-07-02      2.0
# 197000000002         NaN      0.0
# 197001000001         NaN      2.0
# 197001000002         NaN      0.0
# 197001000003         NaN      0.0
# ...                  ...      ...
# 201712310022  2017-12-31      4.0
# 201712310029  2017-12-31     11.0
# 201712310030  2017-12-31      0.0
# 201712310031  2017-12-31      0.0
# 201712310032  2017-12-31      0.0
#
# [181691 rows x 21 columns]
