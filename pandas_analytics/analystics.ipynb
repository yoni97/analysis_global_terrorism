# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../csv_files/globalterrorismdb_1000.csv', encoding='latin1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                     'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                     'nwound': 'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                     'weaptype1_txt':'Weapon_type','motive':'Motive', 'nperps': 'nperps'
                    },inplace=True)
df
# Out:
#           eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0    1.970000e+11  1970      7    2        NaN         0        NaN       58
# 1    1.970000e+11  1970      0    0        NaN         0        NaN      130
# 2    1.970010e+11  1970      1    0        NaN         0        NaN      160
# 3    1.970010e+11  1970      1    0        NaN         0        NaN       78
# 4    1.970010e+11  1970      1    0        NaN         0        NaN      101
# ..            ...   ...    ...  ...        ...       ...        ...      ...
# 995  1.971080e+11  1971      8   30        NaN         0        NaN      217
# 996  1.971090e+11  1971      9    0        NaN         0        NaN       36
# 997  1.971090e+11  1971      9    0        NaN         0        NaN       36
# 998  1.971090e+11  1971      9    1        NaN         0        NaN      217
# 999  1.971090e+11  1971      9    2        NaN         0        NaN      217
#
#                 Country  region  ...  \
# 0    Dominican Republic       2  ...
# 1                Mexico       1  ...
# 2           Philippines       5  ...
# 3                Greece       8  ...
# 4                 Japan       4  ...
# ..                  ...     ...  ...
# 995       United States       1  ...
# 996            Cambodia       5  ...
# 997            Cambodia       5  ...
# 998       United States       1  ...
# 999       United States       1  ...
#
#                                               addnotes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  Robert Miles, Dennis Ramsey, Wallace Fruit, Al...
# 996                                                NaN
# 997                                                NaN
# 998  This attack took place during heightened racia...
# 999  Witnesses saw three males run away from the sc...
#
#                                                 scite1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  "School Buses in Pontiac, Mich., Are Destroyed...
# 996                                                NaN
# 997                                                NaN
# 998  James T. Wooten, "Busing Opposition Stiffens i...
# 999  "Carver School Firebombed at Kannapolis," New ...
#
#                                                 scite2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  William K. Stevens, "5 Ex-Klansmen Convicted i...
# 996                                                NaN
# 997                                                NaN
# 998  Marcia McKnight Trick, "Chronology of Incident...
# 999  James T. Wooten, "Busing Opposition Stiffens i...
#
#                                                 scite3        dbsource  \
# 0                                                  NaN            PGIS
# 1                                                  NaN            PGIS
# 2                                                  NaN            PGIS
# 3                                                  NaN            PGIS
# 4                                                  NaN            PGIS
# ..                                                 ...             ...
# 995  "Bomb Admitted by Dying Klansman," New York Ti...  Hewitt Project
# 996                                                NaN            PGIS
# 997                                                NaN            PGIS
# 998  Christopher Hewitt, "Political Violence and Te...  Hewitt Project
# 999  Marcia McKnight Trick, "Chronology of Incident...  Hewitt Project
#
#      INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0          0         0        0       0      NaN
# 1          0         1        1       1      NaN
# 2         -9        -9        1       1      NaN
# 3         -9        -9        1       1      NaN
# 4         -9        -9        1       1      NaN
# ..       ...       ...      ...     ...      ...
# 995        0         0        0       0      NaN
# 996       -9        -9        1       1      NaN
# 997       -9        -9        1       1      NaN
# 998       -9        -9        0      -9      NaN
# 999       -9        -9        0      -9      NaN
#
# [1000 rows x 135 columns]

# %%
df = df[['eventid','Year','Month','Day','Country','Region','state','city','latitude','longitude','AttackType','Killed','Wounded',
            'Target','Summary','Group','Target_type','Weapon_type','Motive', 'nperps', 'success']]
df
# Out:
#           eventid  Year  Month  Day             Country  \
# 0    1.970000e+11  1970      7    2  Dominican Republic
# 1    1.970000e+11  1970      0    0              Mexico
# 2    1.970010e+11  1970      1    0         Philippines
# 3    1.970010e+11  1970      1    0              Greece
# 4    1.970010e+11  1970      1    0               Japan
# ..            ...   ...    ...  ...                 ...
# 995  1.971080e+11  1971      8   30       United States
# 996  1.971090e+11  1971      9    0            Cambodia
# 997  1.971090e+11  1971      9    0            Cambodia
# 998  1.971090e+11  1971      9    1       United States
# 999  1.971090e+11  1971      9    2       United States
#
#                           Region           state           city   latitude  \
# 0    Central America & Caribbean             NaN  Santo Domingo  18.456792
# 1                  North America         Federal    Mexico city  19.371887
# 2                 Southeast Asia          Tarlac        Unknown  15.478598
# 3                 Western Europe          Attica         Athens  37.997490
# 4                      East Asia         Fukouka        Fukouka  33.580412
# ..                           ...             ...            ...        ...
# 995                North America        Michigan        Pontiac  42.636876
# 996               Southeast Asia      Phnom Penh     Phnom Penh  11.558831
# 997               Southeast Asia      Phnom Penh     Phnom Penh  11.558831
# 998                North America         Georgia       Columbus  32.462925
# 999                North America  North Carolina     Kannapolis  35.487474
#
#       longitude  ... Killed  Wounded  \
# 0    -69.951164  ...    1.0      0.0
# 1    -99.086624  ...    0.0      0.0
# 2    120.599741  ...    1.0      0.0
# 3     23.762728  ...    NaN      NaN
# 4    130.396361  ...    NaN      NaN
# ..          ...  ...    ...      ...
# 995  -83.288425  ...    0.0      0.0
# 996  104.917445  ...    0.0      0.0
# 997  104.917445  ...    2.0     10.0
# 998  -84.987629  ...    0.0      0.0
# 999  -80.622003  ...    0.0      0.0
#
#                                          Target  \
# 0                                  Julio Guzman
# 1                       Nadine Chaval, daughter
# 2                                      Employee
# 3                                  U.S. Embassy
# 4                                U.S. Consulate
# ..                                          ...
# 995            School buses of Pontiac Michigan
# 996                                  Ambassador
# 997                           Embassy personnel
# 998                                         NaN
# 999  George Washington Carver Elementary School
#
#                                                Summary  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  8/30/1971: Ten school buses, that would have b...
# 996                                                NaN
# 997                                                NaN
# 998  9/1/1971: Unknown perpetrators detonated a dyn...
# 999  9/2/1971: Unknown perpetrators threw eight fir...
#
#                                   Group                  Target_type  \
# 0                                MANO-D  Private Citizens & Property
# 1    23rd of September Communist League      Government (Diplomatic)
# 2                               Unknown          Journalists & Media
# 3                               Unknown      Government (Diplomatic)
# 4                               Unknown      Government (Diplomatic)
# ..                                  ...                          ...
# 995                        Ku Klux Klan               Transportation
# 996                             Unknown      Government (Diplomatic)
# 997                             Unknown      Government (Diplomatic)
# 998                    White extremists      Educational Institution
# 999                    White extremists      Educational Institution
#
#     Weapon_type                                  Motive nperps  success
# 0       Unknown                                     NaN    NaN        1
# 1       Unknown                                     NaN    7.0        1
# 2       Unknown                                     NaN    NaN        1
# 3    Explosives                                     NaN    NaN        1
# 4    Incendiary                                     NaN    NaN        1
# ..          ...                                     ...    ...      ...
# 995  Explosives        To prevent school desegregation.    5.0        1
# 996  Explosives                                     NaN    NaN        0
# 997  Explosives                                     NaN    NaN        1
# 998  Explosives  To protest/prevent school integration.  -99.0        1
# 999  Incendiary  To protest/prevent school integration.    3.0        1
#
# [1000 rows x 21 columns]

# %%
print("Country with the most attacks:",df['Country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1]) #first entry is 'unknown'
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Month with the most attacks:",df['Month'].value_counts().idxmax())
print("Group with the most attacks:",df['Group'].value_counts().index[1])
print("Most Attack Types:",df['Weapon_type'].value_counts().idxmax())
# Out:
# Country with the most attacks: United States
# City with the most attacks: Montevideo
# Region with the most attacks: North America
# Year with the most attacks: 1970
# Month with the most attacks: 4
# Group with the most attacks: Left-Wing Militants
# Most Attack Types: Explosives

# %%
df.loc[:, 'Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']], errors='coerce')
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1700\3046581338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']], errors='coerce')
#           eventid  Year  Month  Day             Country  \
# 0    1.970000e+11  1970      7    2  Dominican Republic
# 1    1.970000e+11  1970      0    0              Mexico
# 2    1.970010e+11  1970      1    0         Philippines
# 3    1.970010e+11  1970      1    0              Greece
# 4    1.970010e+11  1970      1    0               Japan
# ..            ...   ...    ...  ...                 ...
# 995  1.971080e+11  1971      8   30       United States
# 996  1.971090e+11  1971      9    0            Cambodia
# 997  1.971090e+11  1971      9    0            Cambodia
# 998  1.971090e+11  1971      9    1       United States
# 999  1.971090e+11  1971      9    2       United States
#
#                           Region           state           city   latitude  \
# 0    Central America & Caribbean             NaN  Santo Domingo  18.456792
# 1                  North America         Federal    Mexico city  19.371887
# 2                 Southeast Asia          Tarlac        Unknown  15.478598
# 3                 Western Europe          Attica         Athens  37.997490
# 4                      East Asia         Fukouka        Fukouka  33.580412
# ..                           ...             ...            ...        ...
# 995                North America        Michigan        Pontiac  42.636876
# 996               Southeast Asia      Phnom Penh     Phnom Penh  11.558831
# 997               Southeast Asia      Phnom Penh     Phnom Penh  11.558831
# 998                North America         Georgia       Columbus  32.462925
# 999                North America  North Carolina     Kannapolis  35.487474
#
#       longitude  ... Wounded                                      Target  \
# 0    -69.951164  ...     0.0                                Julio Guzman
# 1    -99.086624  ...     0.0                     Nadine Chaval, daughter
# 2    120.599741  ...     0.0                                    Employee
# 3     23.762728  ...     NaN                                U.S. Embassy
# 4    130.396361  ...     NaN                              U.S. Consulate
# ..          ...  ...     ...                                         ...
# 995  -83.288425  ...     0.0            School buses of Pontiac Michigan
# 996  104.917445  ...     0.0                                  Ambassador
# 997  104.917445  ...    10.0                           Embassy personnel
# 998  -84.987629  ...     0.0                                         NaN
# 999  -80.622003  ...     0.0  George Washington Carver Elementary School
#
#                                                Summary  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  8/30/1971: Ten school buses, that would have b...
# 996                                                NaN
# 997                                                NaN
# 998  9/1/1971: Unknown perpetrators detonated a dyn...
# 999  9/2/1971: Unknown perpetrators threw eight fir...
#
#                                   Group                  Target_type  \
# 0                                MANO-D  Private Citizens & Property
# 1    23rd of September Communist League      Government (Diplomatic)
# 2                               Unknown          Journalists & Media
# 3                               Unknown      Government (Diplomatic)
# 4                               Unknown      Government (Diplomatic)
# ..                                  ...                          ...
# 995                        Ku Klux Klan               Transportation
# 996                             Unknown      Government (Diplomatic)
# 997                             Unknown      Government (Diplomatic)
# 998                    White extremists      Educational Institution
# 999                    White extremists      Educational Institution
#
#     Weapon_type                                  Motive nperps success  \
# 0       Unknown                                     NaN    NaN       1
# 1       Unknown                                     NaN    7.0       1
# 2       Unknown                                     NaN    NaN       1
# 3    Explosives                                     NaN    NaN       1
# 4    Incendiary                                     NaN    NaN       1
# ..          ...                                     ...    ...     ...
# 995  Explosives        To prevent school desegregation.    5.0       1
# 996  Explosives                                     NaN    NaN       0
# 997  Explosives                                     NaN    NaN       1
# 998  Explosives  To protest/prevent school integration.  -99.0       1
# 999  Incendiary  To protest/prevent school integration.    3.0       1
#
#           Date
# 0   1970-07-02
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT
# ..         ...
# 995 1971-08-30
# 996        NaT
# 997        NaT
# 998 1971-09-01
# 999 1971-09-02
#
# [1000 rows x 22 columns]
